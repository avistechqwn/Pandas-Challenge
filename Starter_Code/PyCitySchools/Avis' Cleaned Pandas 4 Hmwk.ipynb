# %%
# Import Dependencies
import pandas as pd
import os
from pathlib import Path

# %%
# Save path to data set in a variable
schools_complete = r'C:\Users\avisr\OneDrive\Desktop\Avis\GRO MH Tools GRANDE\NORTHWESTERN UNIVERSITY BOOTCAMP\HOMEWORK\PANDAS Hmwk 4\PyCitySchools\Pandas-Challenge\Starter_Code\PyCitySchools\Resources\schools_complete.csv'
students_complete = r'C:\Users\avisr\OneDrive\Desktop\Avis\GRO MH Tools GRANDE\NORTHWESTERN UNIVERSITY BOOTCAMP\HOMEWORK\PANDAS Hmwk 4\PyCitySchools\Pandas-Challenge\Starter_Code\PyCitySchools\Resources\students_complete.csv'

# %%
students_complete_list = [["Student ID", "student_name", "gender", "grade", "school_name", "reading_score", "math_score"]]
schools_complete_list = [["School ID", "school_name", "type", "size", "budget"]]

# %%
# Use Pandas to read data
# Read School and Student Data File and store into Pandas DataFrames
schools_complete_df = pd.read_csv(schools_complete)
schools_complete_df.head()
# Out:
#    School ID            school_name      type  size   budget
# 0          0      Huang High School  District  2917  1910635
# 1          1   Figueroa High School  District  2949  1884411
# 2          2    Shelton High School   Charter  1761  1056600
# 3          3  Hernandez High School  District  4635  3022020
# 4          4    Griffin High School   Charter  1468   917500

# %%
# Use Pandas to read data
# Read School and Student Data File and store into Pandas DataFrames
students_complete_df = pd.read_csv(students_complete)
students_complete_df.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score
# 0             66          79
# 1             94          61
# 2             90          60
# 3             67          58
# 4             97          84

# %%
# Combine the data into a single dataset.  
school_data_complete = pd.merge(students_complete_df, schools_complete_df, on=["school_name"])
school_data_complete
# Out:
#        Student ID       student_name gender grade         school_name  \
# 0               0       Paul Bradley      M   9th   Huang High School
# 1               1       Victor Smith      M  12th   Huang High School
# 2               2    Kevin Rodriguez      M  12th   Huang High School
# 3               3  Dr. Richard Scott      M  12th   Huang High School
# 4               4         Bonnie Ray      F   9th   Huang High School
# ...           ...                ...    ...   ...                 ...
# 39165       39165       Donna Howard      F  12th  Thomas High School
# 39166       39166          Dawn Bell      F  10th  Thomas High School
# 39167       39167     Rebecca Tanner      F   9th  Thomas High School
# 39168       39168       Desiree Kidd      F  10th  Thomas High School
# 39169       39169    Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget
# 0                 66          79          0  District  2917  1910635
# 1                 94          61          0  District  2917  1910635
# 2                 90          60          0  District  2917  1910635
# 3                 67          58          0  District  2917  1910635
# 4                 97          84          0  District  2917  1910635
# ...              ...         ...        ...       ...   ...      ...
# 39165             99          90         14   Charter  1635  1043130
# 39166             95          70         14   Charter  1635  1043130
# 39167             73          84         14   Charter  1635  1043130
# 39168             99          90         14   Charter  1635  1043130
# 39169             95          75         14   Charter  1635  1043130
#
# [39170 rows x 11 columns]

# %%
#4Pandas Day1 Activity 11 Stu_ComicBooksSummarySolved
Total_number_of_unique_schools = len(school_data_complete["school_name"].unique())
Total_number_of_unique_schools
# Out:
# 15

# %%
Total_students = len(school_data_complete["Student ID"])
Total_students
# Out:
# 39170

# %%
total_budget = schools_complete_df['budget'].sum()
total_budget
# Out:
# 24649428

# %%
avg_math_score = school_data_complete['math_score'].mean()
avg_math_score
# Out:
# 78.98537145774827

# %%
avg_reading_score = school_data_complete['reading_score'].mean()
avg_reading_score
# Out:
# 81.87784018381414

# %%
total_students_passed_math = school_data_complete[school_data_complete['math_score'] >= 70].count()["student_name"]
total_students_passed_math
# Out:
# 29370

# %%
total_students_passed_reading = school_data_complete[school_data_complete['reading_score'] >= 70].count()["student_name"]
total_students_passed_reading
# Out:
# 33610

# %%
total_students_passed_both = school_data_complete[(school_data_complete['reading_score'] >=70) & (school_data_complete['math_score'] >= 70)].count()["student_name"]
total_students_passed_both
# Out:
# 25528

# %%
perc_math = (total_students_passed_math/Total_students)*100
perc_math
# Out:
# 74.9808526933878

# %%
perc_reading = (total_students_passed_reading/Total_students)*100
perc_reading
# Out:
# 85.80546336482001

# %%
overall_passing = (total_students_passed_both/Total_students)*100
overall_passing
# Out:
# 65.17232575950983

# %%
#create district summary
district_data_dict = {
    "Total Schools": Total_number_of_unique_schools, 
    "Total Students": Total_students,
    "Total Budget": total_budget,
    "Average Math Score": avg_math_score,
    "Average Reading Score": avg_reading_score, 
    "% Passing Math": perc_math,
    "% Passing Reading": perc_reading,
    "% Overall Passing": overall_passing,    
}

district_summary_df = pd.DataFrame(district_data_dict, index=[0])
district_summary_df
# Out:
#    Total Schools  Total Students  Total Budget  Average Math Score  \
# 0             15           39170      24649428           78.985371
#
#    Average Reading Score  % Passing Math  % Passing Reading  % Overall Passing
# 0               81.87784       74.980853          85.805463          65.172326

# %%
School_Types = schools_complete_df.set_index("school_name")["type"]
#groupby(['school_name'])['type'].unique()
School_Types
# Out:
# school_name
# Huang High School        District
# Figueroa High School     District
# Shelton High School       Charter
# Hernandez High School    District
# Griffin High School       Charter
# Wilson High School        Charter
# Cabrera High School       Charter
# Bailey High School       District
# Holden High School        Charter
# Pena High School          Charter
# Wright High School        Charter
# Rodriguez High School    District
# Johnson High School      District
# Ford High School         District
# Thomas High School        Charter
# Name: type, dtype: object

# %%
School_Names = school_data_complete["school_name"].unique()

print(School_Names)
# Out:
# ['Huang High School' 'Figueroa High School' 'Shelton High School'
#  'Hernandez High School' 'Griffin High School' 'Wilson High School'
#  'Cabrera High School' 'Bailey High School' 'Holden High School'
#  'Pena High School' 'Wright High School' 'Rodriguez High School'
#  'Johnson High School' 'Ford High School' 'Thomas High School']

# %%
# Calculate the total student count per school
per_school_counts = school_data_complete['school_name'].value_counts()
per_school_counts
# Out:
# Bailey High School       4976
# Johnson High School      4761
# Hernandez High School    4635
# Rodriguez High School    3999
# Figueroa High School     2949
# Huang High School        2917
# Ford High School         2739
# Wilson High School       2283
# Cabrera High School      1858
# Wright High School       1800
# Shelton High School      1761
# Thomas High School       1635
# Griffin High School      1468
# Pena High School          962
# Holden High School        427
# Name: school_name, dtype: int64

# %%
# Calculate the total school budget and per capita spending per school

per_school_budget = school_data_complete.groupby(['school_name'])['budget'].mean()
per_school_budget
# Out:
# school_name
# Bailey High School       3124928.0
# Cabrera High School      1081356.0
# Figueroa High School     1884411.0
# Ford High School         1763916.0
# Griffin High School       917500.0
# Hernandez High School    3022020.0
# Holden High School        248087.0
# Huang High School        1910635.0
# Johnson High School      3094650.0
# Pena High School          585858.0
# Rodriguez High School    2547363.0
# Shelton High School      1056600.0
# Thomas High School       1043130.0
# Wilson High School       1319574.0
# Wright High School       1049400.0
# Name: budget, dtype: float64

# %%
per_school_capita = per_school_budget/per_school_counts
per_school_capita
# Out:
# Bailey High School       628.0
# Cabrera High School      582.0
# Figueroa High School     639.0
# Ford High School         644.0
# Griffin High School      625.0
# Hernandez High School    652.0
# Holden High School       581.0
# Huang High School        655.0
# Johnson High School      650.0
# Pena High School         609.0
# Rodriguez High School    637.0
# Shelton High School      600.0
# Thomas High School       638.0
# Wilson High School       578.0
# Wright High School       583.0
# dtype: float64

# %%
# Calculate the average math test scores per school
per_school_math = school_data_complete.groupby(['school_name'])['math_score'].mean()
per_school_math
# Out:
# school_name
# Bailey High School       77.048432
# Cabrera High School      83.061895
# Figueroa High School     76.711767
# Ford High School         77.102592
# Griffin High School      83.351499
# Hernandez High School    77.289752
# Holden High School       83.803279
# Huang High School        76.629414
# Johnson High School      77.072464
# Pena High School         83.839917
# Rodriguez High School    76.842711
# Shelton High School      83.359455
# Thomas High School       83.418349
# Wilson High School       83.274201
# Wright High School       83.682222
# Name: math_score, dtype: float64

# %%
# Calculate the average reading test scores per school
per_school_reading = school_data_complete.groupby(['school_name'])['reading_score'].mean()
per_school_reading
# Out:
# school_name
# Bailey High School       81.033963
# Cabrera High School      83.975780
# Figueroa High School     81.158020
# Ford High School         80.746258
# Griffin High School      83.816757
# Hernandez High School    80.934412
# Holden High School       83.814988
# Huang High School        81.182722
# Johnson High School      80.966394
# Pena High School         84.044699
# Rodriguez High School    80.744686
# Shelton High School      83.725724
# Thomas High School       83.848930
# Wilson High School       83.989488
# Wright High School       83.955000
# Name: reading_score, dtype: float64

# %%
# Calculate the number of students per school with math scores of 70 or higher
schools_passing_math = school_data_complete[school_data_complete['math_score'] >= 70].groupby('school_name')['Student ID'].count()

schools_passing_math
# Out:
# school_name
# Bailey High School       3318
# Cabrera High School      1749
# Figueroa High School     1946
# Ford High School         1871
# Griffin High School      1371
# Hernandez High School    3094
# Holden High School        395
# Huang High School        1916
# Johnson High School      3145
# Pena High School          910
# Rodriguez High School    2654
# Shelton High School      1653
# Thomas High School       1525
# Wilson High School       2143
# Wright High School       1680
# Name: Student ID, dtype: int64

# %%
# Calculate the number of students per school with reading scores of 70 or higher
schools_passing_reading = school_data_complete[school_data_complete['reading_score'] >= 70].groupby('school_name')['Student ID'].count()

schools_passing_reading
# Out:
# school_name
# Bailey High School       4077
# Cabrera High School      1803
# Figueroa High School     2381
# Ford High School         2172
# Griffin High School      1426
# Hernandez High School    3748
# Holden High School        411
# Huang High School        2372
# Johnson High School      3867
# Pena High School          923
# Rodriguez High School    3208
# Shelton High School      1688
# Thomas High School       1591
# Wilson High School       2204
# Wright High School       1739
# Name: Student ID, dtype: int64

# %%
overallpass_df = school_data_complete[(school_data_complete['reading_score'] >=70) & (school_data_complete['math_score'] >= 70)]

ovrall_numbr_pass = overallpass_df.groupby('school_name')['Student ID'].count()

# %%
perc_schools_passing_math = (schools_passing_math / per_school_counts) * 100
perc_schools_passing_reading = (schools_passing_reading / per_school_counts) * 100
perc_overallpass_df = (ovrall_numbr_pass / per_school_counts) * 100

# %%
perc_overallpass_df
# Out:
# Bailey High School       54.642283
# Cabrera High School      91.334769
# Figueroa High School     53.204476
# Ford High School         54.289887
# Griffin High School      90.599455
# Hernandez High School    53.527508
# Holden High School       89.227166
# Huang High School        53.513884
# Johnson High School      53.539172
# Pena High School         90.540541
# Rodriguez High School    52.988247
# Shelton High School      89.892107
# Thomas High School       90.948012
# Wilson High School       90.582567
# Wright High School       90.333333
# dtype: float64

# %%
#create district summary
SCHOOL_data_dict = {
    "School Types": School_Types,
    "Total Students": per_school_counts,
    "Total School Budget": per_school_budget,
    "Per Student Budget": per_school_capita,
    "Average Scl Math Score": per_school_math,
    "Average Scl Reading Score": per_school_reading, 
    "SCL % Passing Math": perc_schools_passing_math,
    "SCL % Passing Reading": perc_schools_passing_reading,
    "SCL % Overall Passing": perc_overallpass_df    
}


# Create a DataFrame called `per_school_summary` with columns for the calculations above.
per_school_summary = pd.DataFr
# Cabrera High School      Charter            1858            1081356.0
# Thomas High School       Charter            1635            1043130.0
# Griffin High School      Charter            1468             917500.0
# Wilson High School       Charter            2283            1319574.0
# Pena High School         Charter             962             585858.0
#
#                      Per Student Budget  Average Scl Math Score  \
# Cabrera High School               582.0               83.061895
# Thomas High School                638.0               83.418349
# Griffin High School               625.0               83.351499
# Wilson High School                578.0               83.274201
# Pena High School                  609.0               83.839917
#
#                      Average Scl Reading Score  SCL % Passing Math  \
# Cabrera High School                  83.975780           94.133477
# Thomas High School                   83.848930           93.272171
# Griffin High School                  83.816757           93.392371
# Wilson High School                   83.989488           93.867718
# Pena High School                     84.044699           94.594595
#
#                      SCL % Passing Reading  SCL % Overall Passing
# Cabrera High School              97.039828              91.334769
# Thomas High School               97.308869              90.948012
# Griffin High School              97.138965              90.599455
# Wilson High School               96.539641              90.582567
# Pena High School                 95.945946              90.540541

# %%
bottom_schools = per_school_summary.sort_values("SCL % Overall Passing")
bottom_schools.head(5)
# Out:
#                       School Types  Total Students  Total School Budget  \
# Rodriguez High School     District            3999            2547363.0
# Figueroa High School      District            2949            1884411.0
# Huang High School         District            2917            1910635.0
# Hernandez High School     District            4635            3022020.0
# Johnson High School       District            4761            3094650.0
#
#                        Per Student Budget  Average Scl Math Score  \
# Rodriguez High School               637.0               76.842711
# Figueroa High School                639.0               76.711767
# Huang High School                   655.0               76.629414
# Hernandez High School               652.0               77.289752
# Johnson High School                 650.0               77.072464
#
#                        Average Scl Reading Score  SCL % Passing Math  \
# Rodriguez High School                  80.744686           66.366592
# Figueroa High School                   81.158020           65.988471
# Huang High School                      81.182722           65.683922
# Hernandez High School                  80.934412           66.752967
# Johnson High School                    80.966394           66.057551
#
#                        SCL % Passing Reading  SCL % Overall Passing
# Rodriguez High School              80.220055              52.988247
# Figueroa High School               80.739234              53.204476
# Huang High School                  81.316421              53.513884
# Hernandez High School              80.862999              53.527508
# Johnson High School                81.222432              53.539172

# %%
#Sort descending (high to low) use ascending=False
ninethgrders = school_data_complete[(school_data_complete['grade'] == "9th")]
ng_hms = ninethgrders.groupby('school_name')['math_score'].mean()
ng_hms

tenthgrders = school_data_complete[(school_data_complete['grade'] == "10th")]
tengr_hms = tenthgrders.groupby('school_name')['math_score'].mean()
tengr_hms

elevthgrders = school_data_complete[(school_data_complete['grade'] == "11th")]
elvng_hms = elevthgrders.groupby('school_name')['math_score'].mean()
elvng_hms

twlvfgrders = school_data_complete[(school_data_complete['grade'] == "12th")]
twlg_hms = twlvfgrders.groupby('school_name')['math_score'].mean()
twlg_hms

#create district summary
MGrades_data_dict = {
    "Nineth Grd Scrs" : ng_hms,
    "Tenth Grd Scrs" : tengr_hms,
    "Eleventh Grd Scrs" : elvng_hms,
    "Twelveth Grd Scrs" : twlg_hms      
}

math_scores_by_grade = pd.DataFrame(MGrades_data_dict)
math_scores_by_grade
# Out:
#                        Nineth Grd Scrs  Tenth Grd Scrs  Eleventh Grd Scrs  \
# school_name
# Bailey High School           77.083676       76.996772          77.515588
# Cabrera High School          83.094697       83.154506          82.765560
# Figueroa High School         76.403037       76.539974          76.884344
# Ford High School             77.361345       77.672316          76.918058
# Griffin High School          82.044010       84.229064          83.842105
# Hernandez High School        77.438495       77.337408          77.136029
# Holden High School           83.787402       83.429825          85.000000
# Huang High School            77.027251       75.908735          76.446602
# Johnson High School          77.187857       76.691117          77.491653
# Pena High School             83.625455       83.372000          84.328125
# Rodriguez High School        76.859966       76.612500          76.395626
# Shelton High School          83.420755       82.917411          83.383495
# Thomas High School           83.590022       83.087886          83.498795
# Wilson High School           83.085578       83.724422          83.195326
# Wright High School           83.264706       84.010288          83.836782
#
#                        Twelveth Grd Scrs
# school_name
# Bailey High School             76.492218
# Cabrera High School            83.277487
# Figueroa High School           77.151369
# Ford High School               76.179963
# Griffin High School            83.356164
# Hernandez High School          77.186567
# Holden High School             82.855422
# Huang High School              77.225641
# Johnson High School            76.863248
# Pena High School               84.121547
# Rodriguez High School          77.690748
# Shelton High School            83.778976
# Thomas High School             83.497041
# Wilson High School             83.035794
# Wright High School             83.644986

# %%
rninethgrders = school_data_complete[(school_data_complete['grade'] == "9th")]
rng_hms = rninethgrders.groupby('school_name')['reading_score'].mean()
rng_hms

rtenthgrders = school_data_complete[(school_data_complete['grade'] == "10th")]
rtengr_hms = rtenthgrders.groupby('school_name')['reading_score'].mean()
rtengr_hms

relevthgrders = school_data_complete[(school_data_complete['grade'] == "11th")]
relvng_hms = relevthgrders.groupby('school_name')['reading_score'].mean()
relvng_hms

rtwlvfgrders = school_data_complete[(school_data_complete['grade'] == "12th")]
rtwlg_hms = rtwlvfgrders.groupby('school_name')['reading_score'].mean()
rtwlg_hms




RGrades_data_dict = {
    "RNineth Grd Scrs" : rng_hms,
    "RTenth Grd Scrs" : rtengr_hms,
    "REleventh Grd Scrs" : relvng_hms,
    "RTwelveth Grd Scrs" : rtwlg_hms      
}

reading_scores_by_grade = pd.DataFrame(RGrades_data_dict)
reading_scores_by_grade
# Out:
#                        RNineth Grd Scrs  RTenth Grd Scrs  REleventh Grd Scrs  \
# school_name
# Bailey High School            81.303155        80.907183           80.945643
# Cabrera High School           83.676136        84.253219           83.788382
# Figueroa High School          81.198598        81.408912           80.640339
# Ford High School              80.632653        81.262712           80.403642
# Griffin High School           83.369193        83.706897           84.288089
# Hernandez High School         80.866860        80.660147           81.396140
# Holden High School            83.677165        83.324561           83.815534
# Huang High School             81.290284        81.512386           81.417476
# Johnson High School           81.260714        80.773431           80.616027
# Pena High School              83.807273        83.612000           84.335938
# Rodriguez High School         80.993127        80.629808           80.864811
# Shelton High School           84.122642        83.441964           84.373786
# Thomas High School            83.728850        84.254157           83.585542
# Wilson High School            83.939778        84.021452           83.764608
# Wright High School            83.833333        83.812757           84.156322
#
#                        RTwelveth Grd Scrs
# school_name
# Bailey High School              80.912451
# Cabrera High School             84.287958
# Figueroa High School            81.384863
# Ford High School                80.662338
# Griffin High School             84.013699
# Hernandez High School           80.857143
# Holden High School              84.698795
# Huang High School               80.305983
# Johnson High School             81.227564
# Pena High School                84.591160
# Rodriguez High School           80.376426
# Shelton High School             82.781671
# Thomas High School              83.831361
# Wilson High School              84.317673
# Wright High School              84.073171

# %%
top_schools_sorted = overallpass_df.sort_values(by='school_name', ascending = False)

top_schools_sorted
# Out:
#        Student ID      student_name gender grade         school_name  \
# 24253       24253  Phillip Martinez      M  10th  Wright High School
# 24636       24636    Anthony Snyder      M  11th  Wright High School
# 24624       24624        Amy Ramsey      F   9th  Wright High School
# 24625       24625        Molly Cruz      F  10th  Wright High School
# 24626       24626   Jennifer Cooper      F   9th  Wright High School
# ...           ...               ...    ...   ...                 ...
# 21221       21221     Kevin Flowers      M  10th  Bailey High School
# 21219       21219     Pamela Hunter      F  11th  Bailey High School
# 21215       21215        Daniel Lee      M  10th  Bailey High School
# 21214       21214        Tara Marsh      F   9th  Bailey High School
# 18772       18772     Brandi Little      F  11th  Bailey High School
#
#        reading_score  math_score  School ID      type  size   budget
# 24253             97          91         10   Charter  1800  1049400
# 24636             77          77         10   Charter  1800  1049400
# 24624             92          89         10   Charter  1800  1049400
# 24625             76          85         10   Charter  1800  1049400
# 24626             99          76         10   Charter  1800  1049400
# ...              ...         ...        ...       ...   ...      ...
# 21221             92          76          7  District  4976  3124928
# 21219             74          82          7  District  4976  3124928
# 21215             73          74          7  District  4976  3124928
# 21214             94          90          7  District  4976  3124928
# 18772             98          91          7  District  4976  3124928
#
# [25528 rows x 11 columns]

# %%
bottom_schools_sorted = overallpass_df.sort_values(by='school_name', ascending = False)

bottom_schools_sorted.tail(5)
# Out:
#        Student ID   student_name gender grade         school_name  \
# 21221       21221  Kevin Flowers      M  10th  Bailey High School
# 21219       21219  Pamela Hunter      F  11th  Bailey High School
# 21215       21215     Daniel Lee      M  10th  Bailey High School
# 21214       21214     Tara Marsh      F   9th  Bailey High School
# 18772       18772  Brandi Little      F  11th  Bailey High School
#
#        reading_score  math_score  School ID      type  size   budget
# 21221             92          76          7  District  4976  3124928
# 21219             74          82          7  District  4976  3124928
# 21215             73          74          7  District  4976  3124928
# 21214             94          90          7  District  4976  3124928
# 18772             98          91          7  District  4976  3124928

# %%
mathsc_by_grade_df = overallpass_df.groupby('grade').mean ()
mathsc_by_grade_df
# Out:
#          Student ID  reading_score  math_score  School ID         size  \
# grade
# 10th   19581.953853      84.376414   84.520887   6.980244  3036.517871
# 11th   19680.859655      84.585617   84.485665   7.023127  3043.698400
# 12th   19371.297271      84.498635   84.493177   6.901170  3042.190253
# 9th    19658.991146      84.391199   84.347196   7.005635  3073.344915
#
#              budget
# grade
# 10th   1.916929e+06
# 11th   1.920536e+06
# 12th   1.920494e+06
# 9th    1.941771e+06

# Pena High School                       84.044699           94.594595
# Rodriguez High School                  80.744686           66.366592
# Shelton High School                    83.725724           93.867121
# Thomas High School                     83.848930           93.272171
# Wilson High School                     83.989488           93.867718
# Wright High School                     83.955000           93.333333
#
#                        SCL % Passing Reading  SCL % Overall Passing  \
# Bailey High School                 81.933280              54.642283
# Cabrera High School                97.039828              91.334769
# Figueroa High School               80.739234              53.204476
# Ford High School                   79.299014              54.289887
# Griffin High School                97.138965              90.599455
# Hernandez High School              80.862999              53.527508
# Holden High School                 96.252927              89.227166
# Huang High School                  81.316421              53.513884
# Johnson High School                81.222432              53.539172
# Pena High School                   95.945946              90.540541
# Rodriguez High School              80.220055              52.988247
# Shelton High School                95.854628              89.892107
# Thomas High School                 97.308869              90.948012
# Wilson High School                 96.539641              90.582567
# Wright High School                 96.611111              90.333333
#
#                       Spending Per Student
# Bailey High School                $585-630
# Cabrera High School                  <$585
# Figueroa High School              $630-645
# Ford High School                  $630-645
# Griffin High School               $585-630
# Hernandez High School             $645-680
# Holden High School                   <$585
# Huang High School                 $645-680
# Johnson High School               $645-680
# Pena High School                  $585-630
# Rodriguez High School             $630-645
# Shelton High School               $585-630
# Thomas High School                $630-645
# Wilson High School                   <$585
# Wright High School                   <$585

# %%
spending_math_scores = per_school_summary.groupby(["Spending Per Student"]).mean()["Average Scl Math Score"]
spending_reading_scores = per_school_summary.groupby(["Spending Per Student"]).mean()["Average Scl Reading Score"]
spending_passing_math = per_school_summary.groupby(["Spending Per Student"]).mean()["SCL % Passing Math"]
spending_passing_reading = per_school_summary.groupby(["Spending Per Student"]).mean()["SCL % Passing Reading"]
overall_passing_spending = per_school_summary.groupby(["Spending Per Student"]).mean()["SCL % Overall Passing"]

#create district summary
spending_data_dict = {
    "Average Scl Math Score": Total_students,
    "Average Scl Reading Score": total_budget,
    "SCL % Passing Math": avg_math_score,
    "SCL % Passing Reading": avg_reading_score, 
    "% Passing Math": perc_math,
    "% Passing Reading": perc_reading,
    "% Overall Passing": overall_passing,    
}

Spending_summary_df = pd.DataFrame(spending_data_dict, index=[0])
Spending_summary_df
# Out:
#    Average Scl Math Score  Average Scl Reading Score  SCL % Passing Math  \
# 0                   39170                   24649428           78.985371
#
#    SCL % Passing Reading  % Passing Math  % Passing Reading  % Overall Passing
# 0               81.87784       74.980853          85.805463          65.172326

# %%
spending_bins = [0, 585, 630, 645, 680]
labels = ["<$585", "$585-630", "$630-645", "$645-680"]



per_school_summary["Spending Per Student"] = pd.cut(per_school_summary["Per Student Budget"], spending_bins, labels=labels)
per_school_summary
# Out:
#                       School Types  Total Students  Total School Budget  \
# Bailey High School        District            4976            3124928.0
# Cabrera High School        Charter            1858            1081356.0
# Figueroa High School      District            2949            1884411.0
# Ford High School          District            2739            1763916.0
# Griffin High School        Charter            1468             917500.0
# Hernandez High School     District            4635            3022020.0
# Holden High School         Charter             427             248087.0
# Huang High School         District            2917            1910635.0
# Johnson High School       District            4761            3094650.0
# Pena High School           Charter             962             585858.0
# Rodriguez High School     District            3999            2547363.0
# Shelton High School        Charter            1761            1056600.0
# Thomas High School         Charter            1635            1043130.0
